# %%
from models.embedding_model import EmbeddingModel
from models.llm_model import LLMModel
from rag.retriever import Retriever
from rag.generator import Generator
from rag.orchestrator import RAGOrchestrator
from ingestion.ingestion import ingest_documents
# from ingestion.chunker import Chunker
from rag.guard import Guard
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from models.embedding_model import EmbeddingModel
#       2 from models.llm_model import LLMModel
#       3 from rag.retriever import Retriever
#
# ModuleNotFoundError: No module named 'models'

# %%
import torch
from transformers import AutoTokenizer,AutoModelForCausalLM
from sentence_transformers import SentenceTransformer
import os
import uuid
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import torch
#       2 from transformers import AutoTokenizer,AutoModelForCausalLM
#       3 from sentence_transformers import SentenceTransformer
#
# ModuleNotFoundError: No module named 'torch'

# %%
import chromadb 
from chromadb.config  import Settings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import chromadb
#       2 from chromadb.config  import Settings
#
# ModuleNotFoundError: No module named 'chromadb'

# %%
from config.config import (LLM_MODEL_NAME,MAX_NEW_TOKENS,MAX_CONTEXT_TOKENS,TEMPERATURE,DO_SAMPLE,CHUNK_SIZE,CHUNK_OVERLAP,RAW_DOCS_PATH,SIMILARITY_THRESHOLD,CHROMA_DB_PATH,TOP_K,EMBEDDING_MODEL_NAME)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from config.config import (LLM_MODEL_NAME,MAX_NEW_TOKENS,MAX_CONTEXT_TOKENS,TEMPERATURE,DO_SAMPLE,CHUNK_SIZE,CHUNK_OVERLAP,RAW_DOCS_PATH,SIMILARITY_THRESHOLD,CHROMA_DB_PATH,TOP_K,EMBEDDING_MODEL_NAME)
#
# ModuleNotFoundError: No module named 'config'

# %%
ingest_documents()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ingest_documents()
#
# NameError: name 'ingest_documents' is not defined

# %%
retriever = Retriever()
print(retriever.collection.count())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 retriever = Retriever()
#       2 print(retriever.collection.count())
#
# NameError: name 'Retriever' is not defined

# %%
embedding_model = EmbeddingModel()
query = "test query"
query_embedding = embedding_model.embed([query])[0]
results = retriever.retrieve(query_embedding)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 embedding_model = EmbeddingModel()
#       2 query = "test query"
#       3 query_embedding = embedding_model.embed([query])[0]
#
# NameError: name 'EmbeddingModel' is not defined

# %%
documents = results["documents"][0]
distances = results["distances"][0]
for doc,dist in zip(documents,distances):
    similarity = 1-dist
    print("Similarity:",similarity)
    print("Chunk:",doc[:200])
    print("-"*50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 documents = results["documents"][0]
#       2 distances = results["distances"][0]
#       3 for doc,dist in zip(documents,distances):
#
# NameError: name 'results' is not defined

# %%
filtered = Guard.filter_results(results)
for chunk in filtered:
    print(chunk["similarity"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 filtered = Guard.filter_results(results)
#       2 for chunk in filtered:
#       3     print(chunk["similarity"])
#
# NameError: name 'Guard' is not defined

# %%
llm_model = LLMModel()
generator = Generator(llm_model)
orchestrator = RAGOrchestrator(embedding_model,retriever,generator)
response = orchestrator.run(query)
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 llm_model = LLMModel()
#       2 generator = Generator(llm_model)
#       3 orchestrator = RAGOrchestrator(embedding_model,retriever,generator)
#
# NameError: name 'LLMModel' is not defined

# %%
PROMPT_TEMPLATE = """
					You are an Enterprise Knowledge Assistant.

			        Use OnLY the provided context to answer the question.
			        if the answer is notexplicitely contained in the context, say you do not know.
			        
			        Context:
			        {context}
			        
			        Question:
			        {query}
			        
			        Answer:

				  """

REFUSAL_MESSAGE = "I do not have sufficient information in the knowledge base to answer this question."
